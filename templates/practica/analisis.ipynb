# %% [markdown]
# # Práctica NN — Título del experimento
#
# **Fecha:** YYYY-MM-DD
# **Integrantes:** nombre(s)
#
# ---

# %% [markdown]
# ## 0. Importaciones y configuración

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats, optimize
import sys
import os

# Agrega scripts/ al path para importar utils.
# Este notebook debe ejecutarse desde su propia carpeta (practicas/pNN-nombre/).
REPO_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))
sys.path.insert(0, os.path.join(REPO_ROOT, 'scripts'))
# from utils import ajuste_lineal, formato_resultado  # descomentar cuando esté disponible

# Estilo de gráficos
plt.rcParams.update({
    'figure.dpi': 120,
    'font.size': 12,
    'axes.grid': True,
    'grid.alpha': 0.3,
})

# %% [markdown]
# ## 1. Carga de datos

# %%
# Ajustar la ruta según el archivo de datos
# df = pd.read_csv('datos/crudos/medicion_YYYY-MM-DD.csv')
# df.head()

# %% [markdown]
# ## 2. Exploración y limpieza

# %%
# Revisar tipos, valores faltantes, estadísticas básicas
# df.info()
# df.describe()

# %% [markdown]
# ## 3. Análisis

# %%
# Ajuste, cálculos, propagación de errores, etc.

# %% [markdown]
# ## 4. Visualización

# %%
fig, ax = plt.subplots(figsize=(7, 4))

# ax.errorbar(x, y, yerr=dy, fmt='o', capsize=4, label='Datos')
# ax.plot(x_fit, y_fit, '-', label='Ajuste')

ax.set_xlabel('Variable x [unidad]')
ax.set_ylabel('Variable y [unidad]')
ax.set_title('Título del gráfico')
ax.legend()

fig.tight_layout()
# fig.savefig('figuras/fig_descripcion.pdf')  # descomentar para guardar
plt.show()

# %% [markdown]
# ## 5. Resultados y conclusiones

# %%
# Imprimir resultados con incertezas
# print(f'Resultado: {valor:.4f} ± {incerteza:.4f} [unidades]')

# %% [markdown]
# ---
# ### Notas
#
# - …
